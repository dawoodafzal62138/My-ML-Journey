# %% [markdown]
# # **Image Processor Without Libraries**

# %% [markdown]
# 1. import necessary libraries

# %%
import numpy as np
import pathlib 
from PIL import Image

# %%
path  = pathlib.path(__file__).parent.resolve() / "images.jpg"
image = image.open()
